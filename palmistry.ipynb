# %%
# import numpy as np
# import tensorflow as tf
# import pandas as pd
# from tensorflow.keras.preprocessing.image import ImageDataGenerator
# from tensorflow.keras.models import Sequential
# from tensorflow.keras.layers import Conv2D, MaxPooling2D, Flatten, Dense
# import os

# # Directory path containing images and CSV file
# data_dir = '/kaggle/input/hands-and-palm-images-dataset/Hands/Hands'  # Replace with your directory path

# # Read CSV file
# csv_path = os.path.join(data_dir, '/kaggle/input/hands-and-palm-images-dataset/HandInfo.csv')  # Replace 'your_csv_file.csv' with your CSV filename
# data_df = pd.read_csv(csv_path)

# # ImageDataGenerator
# datagen = ImageDataGenerator(rescale=1./255, validation_split=0.2)

# train_generator = datagen.flow_from_dataframe(
#     dataframe=data_df,
#     directory=os.path.join(data_dir, 'images'),  # Directory containing images
#     x_col='imageName',
#     y_col=['age', 'gender', 'skinColor', 'accessories', 'nailPolish', 'aspectOfHand', 'irregularities'],
#     target_size=(150, 150),
#     batch_size=32,
#     class_mode='multi_output',
#     subset='training'
# )

# validation_generator = datagen.flow_from_dataframe(
#     dataframe=data_df,
#     directory=os.path.join(data_dir, 'images'),  # Directory containing images
#     x_col='imageName',
#     y_col=['age', 'gender', 'skinColor', 'accessories', 'nailPolish', 'aspectOfHand', 'irregularities'],
#     target_size=(150, 150),
#     batch_size=32,
#     class_mode='multi_output',
#     subset='validation'
# )

# # Build CNN model
# model = Sequential([
#     Conv2D(32, (3, 3), activation='relu', input_shape=(150, 150, 3)),
#     MaxPooling2D(2, 2),
#     Conv2D(64, (3, 3), activation='relu'),
#     MaxPooling2D(2, 2),
#     Flatten(),
#     Dense(128, activation='relu'),
#     Dense(7, activation='softmax')  # 7 units for 7 outputs
# ])

# model.compile(optimizer='adam', loss='mse', metrics=['accuracy'])

# # Train the model
# model.fit(train_generator, validation_data=validation_generator, epochs=1)

# %%
# import numpy as np
# import tensorflow as tf
# import pandas as pd
# from tensorflow.keras.preprocessing.image import ImageDataGenerator
# from tensorflow.keras.models import Sequential
# from tensorflow.keras.layers import Conv2D, MaxPooling2D, Flatten, Dense
# import os
# from tensorflow.keras.layers import Input

# # Directory path containing images and CSV file
# data_dir = '/kaggle/input/hands-and-palm-images-dataset'

# # Read CSV file
# csv_path = os.path.join(data_dir, '/kaggle/input/hands-and-palm-images-dataset/HandInfo.csv')  # Corrected CSV path
# data_df = pd.read_csv(csv_path)

# # ImageDataGenerator
# datagen = ImageDataGenerator(rescale=1./255, validation_split=0.2)

# train_generator = datagen.flow_from_dataframe(
#     dataframe=data_df,
#     directory=os.path.join(data_dir, 'images'),  # Directory containing images
#     x_col='imageName',
#     y_col=['age', 'gender', 'skinColor', 'accessories', 'nailPolish', 'aspectOfHand', 'irregularities'],
#     target_size=(150, 150),
#     batch_size=32,
#     class_mode='multi_output',
#     subset='training'
# )

# validation_generator = datagen.flow_from_dataframe(
#     dataframe=data_df,
#     directory=os.path.join(data_dir, 'images'),  # Directory containing images
#     x_col='imageName',
#     y_col=['age', 'gender', 'skinColor', 'accessories', 'nailPolish', 'aspectOfHand', 'irregularities'],
#     target_size=(150, 150),
#     batch_size=32,
#     class_mode='multi_output',
#     subset='validation'
# )

# # Build CNN model



# model = Sequential([
#     Input(shape=(150, 150, 3)),
#     Conv2D(32, (3, 3), activation='relu'),
#     MaxPooling2D(2, 2),
#     Conv2D(64, (3, 3), activation='relu'),
#     MaxPooling2D(2, 2),
#     Flatten(),
#     Dense(128, activation='relu'),
#     Dense(7, activation='softmax')
# ])

# model.compile(optimizer='adam', loss='mse', metrics=['accuracy'])

# # Train the model
# model.fit(train_generator, validation_data=validation_generator, epochs=1)

# %%
# import numpy as np
# import pandas as pd
# import tensorflow as tf
# from tensorflow.keras.preprocessing.image import ImageDataGenerator
# from tensorflow.keras.models import Sequential
# from tensorflow.keras.layers import Conv2D, MaxPooling2D, Flatten, Dense

# # Read CSV file
# csv_path = '/kaggle/input/hands-and-palm-images-dataset/HandInfo.csv'
# metadata_df = pd.read_csv(csv_path)

# # Load dataset
# datagen = ImageDataGenerator(rescale=1./255, validation_split=0.2)

# def custom_data_generator(generator, metadata_df, batch_size):
#     for x_batch in generator:
#         # Extract image names from the current batch
#         image_names = [path.split('/')[-1] for path in generator.filenames[generator.batch_index * batch_size : (generator.batch_index + 1) * batch_size]]
        
#         # Extract metadata for the current batch of images
#         batch_metadata = metadata_df[metadata_df['imageName'].isin(image_names)]
        
#         # Extract labels from metadata
#         labels = batch_metadata[['age', 'gender', 'skinColor', 'accessories', 'nailPolish', 'aspectOfHand']].values
        
#         yield x_batch, labels



# train_generator = datagen.flow_from_directory(
#     '/kaggle/input/hands-and-palm-images-dataset',
#     target_size=(150, 150),
#     batch_size=32,
#     class_mode=None,
#     subset='training'
# )

# validation_generator = datagen.flow_from_directory(
#     '/kaggle/input/hands-and-palm-images-dataset',
#     target_size=(150, 150),
#     batch_size=32,
#     class_mode=None,
#     subset='validation'
# )

# # Build CNN model
# model = Sequential([
#     Conv2D(32, (3, 3), activation='relu', input_shape=(150, 150, 3)),
#     MaxPooling2D(2, 2),
#     Conv2D(64, (3, 3), activation='relu'),
#     MaxPooling2D(2, 2),
#     Flatten(),
#     Dense(128, activation='relu'),
#     Dense(6, activation='softmax')  # 6 units for 6 metadata columns
# ])

# model.compile(optimizer='adam', loss='mse', metrics=['accuracy'])  # Using MSE for regression

# # Train the model
# model.fit(custom_data_generator(train_generator, metadata_df, 32),
#           validation_data=custom_data_generator(validation_generator, metadata_df, 32),
#           steps_per_epoch=len(train_generator),
#           validation_steps=len(validation_generator),
#           epochs=1)

# %%
import numpy as np
import pandas as pd
import tensorflow as tf
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Flatten, Dense

# Read CSV file
csv_path = '/kaggle/input/hands-and-palm-images-dataset/HandInfo.csv'
metadata_df = pd.read_csv(csv_path)

# Load dataset
datagen = ImageDataGenerator(rescale=1./255, validation_split=0.2)

def custom_data_generator(generator, metadata_df, batch_size):
    while True:
        x_batch = next(generator)
        image_names = [generator.filenames[i].split('/')[-1] for i in range(len(x_batch))]
 # Extract filenames
        batch_metadata = metadata_df[metadata_df['imageName'].isin(image_names)]
        
        print("Image names:", image_names)  # Debugging line
        print("Batch metadata shape:", batch_metadata.shape)  # Debugging line
        
        # Extract labels from metadata
        
        # One-hot encoding categorical columns
        encoded_metadata = pd.get_dummies(batch_metadata, columns=['gender', 'skinColor', 'accessories', 'nailPolish', 'aspectOfHand', 'irregularities'])

        # Drop non-numeric columns
        encoded_metadata.drop(['imageName'], axis=1, inplace=True)

      
        # Extract labels
        labels = encoded_metadata[['id', 'age']].astype('float32').values
        


        
        print("Labels shape:", labels.shape)  # Debugging line
        
        yield x_batch, labels




train_generator = datagen.flow_from_directory(
    '/kaggle/input/hands-and-palm-images-dataset',
    target_size=(150, 150),
    batch_size=32,
    class_mode=None,
    subset='training'
)

validation_generator = datagen.flow_from_directory(
    '/kaggle/input/hands-and-palm-images-dataset',
    target_size=(150, 150),
    batch_size=32,
    class_mode=None,
    subset='validation'
)

# Build CNN model
model = Sequential([
    Conv2D(32, (3, 3), activation='relu', input_shape=(150, 150, 3)),
    MaxPooling2D(2, 2),
    Conv2D(64, (3, 3), activation='relu'),
    MaxPooling2D(2, 2),
    Flatten(),
    Dense(128, activation='relu'),
    Dense(2)  # Adjusted to 2 units
])





model.compile(optimizer='adam', loss='mse', metrics=['accuracy'])

# Train the model
model.fit(custom_data_generator(train_generator, metadata_df, 32),
          validation_data=custom_data_generator(validation_generator, metadata_df, 32),
          steps_per_epoch=len(train_generator),
          validation_steps=len(validation_generator),
          epochs=1)
# Out:
# 2024-05-05 07:01:21.011891: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-05-05 07:01:21.011986: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-05-05 07:01:21.152724: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# Found 8861 images belonging to 1 classes.
# Found 2215 images belonging to 1 classes.
# ...

# %%
from PIL import Image
import matplotlib.pyplot as plt
from keras.preprocessing import image
import numpy as np

# Load the image
img_path = "/kaggle/input/hands-and-palm-images-dataset/Hands/Hands/Hand_0000032.jpg"
img = Image.open(img_path)

# Display the image
plt.imshow(img)
plt.axis('off')
plt.show()

# Resize the image
resized_img = img.resize((150, 150))

# Convert resized image to array
img_array = image.img_to_array(resized_img)

# Normalize the image data
img_array = img_array / 255.0

# Reshape the array to match the expected input shape of the model
img_array_reshaped = img_array.reshape(1, 150, 150, 3)

# Make predictions
predictions = model.predict(img_array_reshaped)
# Out:
# 2024-05-05 07:03:44.075409: E external/local_xla/xla/service/gpu/buffer_comparator.cc:1137] Difference at 30560: 4.13759, expected 3.62039
# 2024-05-05 07:03:44.075462: E external/local_xla/xla/service/gpu/buffer_comparator.cc:1137] Difference at 30689: 4.16181, expected 3.6446
# 2024-05-05 07:03:44.075512: E external/local_xla/xla/service/gpu/buffer_comparator.cc:1137] Difference at 40495: 4.13759, expected 3.62039
# 2024-05-05 07:03:44.075520: E external/local_xla/xla/service/gpu/buffer_comparator.cc:1137] Difference at 40624: 4.16181, expected 3.6446
# 2024-05-05 07:03:44.075546: E external/local_xla/xla/service/gpu/buffer_comparator.cc:1137] Difference at 44990: 4.55328, expected 3.99621
# 2024-05-05 07:03:44.075562: E external/local_xla/xla/service/gpu/buffer_comparator.cc:1137] Difference at 47010: 4.40387, expected 3.8468
# 2024-05-05 07:03:44.075570: E external/local_xla/xla/service/gpu/buffer_comparator.cc:1137] Difference at 47030: 4.30735, expected 3.75029
# ...

# %%
import numpy as np
import pandas as pd
import tensorflow as tf
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Flatten, Dense
from sklearn.metrics import precision_score, f1_score

# Read CSV file
csv_path = '/kaggle/input/hands-and-palm-images-dataset/HandInfo.csv'
metadata_df = pd.read_csv(csv_path)

# Load dataset
datagen = ImageDataGenerator(rescale=1./255, validation_split=0.2)

def custom_data_generator(generator, metadata_df, batch_size):
    while True:
        x_batch = next(generator)
        image_names = [generator.filenames[i].split('/')[-1] for i in range(len(x_batch))]
        
        batch_metadata = metadata_df[metadata_df['imageName'].isin(image_names)]
        
        encoded_metadata = pd.get_dummies(batch_metadata, columns=['gender', 'skinColor', 'accessories', 'nailPolish', 'aspectOfHand', 'irregularities'])
        encoded_metadata.drop(['imageName'], axis=1, inplace=True)
        
        labels = encoded_metadata[['id', 'age']].astype('float32').values
        
        yield x_batch, labels

train_generator = datagen.flow_from_directory(
    '/kaggle/input/hands-and-palm-images-dataset',
    target_size=(150, 150),
    batch_size=32,
    class_mode=None,
    subset='training'
)

validation_generator = datagen.flow_from_directory(
    '/kaggle/input/hands-and-palm-images-dataset',
    target_size=(150, 150),
    batch_size=32,
    class_mode=None,
    subset='validation'
)

def f1_metric(y_true, y_pred):
    y_pred = tf.round(y_pred)
    tp = tf.keras.backend.sum(tf.cast(y_true * y_pred, 'float'), axis=0)
    tn = tf.keras.backend.sum(tf.cast((1 - y_true) * (1 - y_pred), 'float'), axis=0)
    fp = tf.keras.backend.sum(tf.cast((1 - y_true) * y_pred, 'float'), axis=0)
    fn = tf.keras.backend.sum(tf.cast(y_true * (1 - y_pred), 'float'), axis=0)
    
    precision = tp / (tp + fp + tf.keras.backend.epsilon())
    recall = tp / (tp + fn + tf.keras.backend.epsilon())
    
    f1 = 2 * precision * recall / (precision + recall + tf.keras.backend.epsilon())
    f1 = tf.where(tf.math.is_nan(f1), tf.zeros_like(f1), f1)
    
    return tf.reduce_mean(f1)

def precision_metric(y_true, y_pred):
    y_pred = tf.round(y_pred)
    tp = tf.keras.backend.sum(tf.cast(y_true * y_pred, 'float'), axis=0)
    fp = tf.keras.backend.sum(tf.cast((1 - y_true) * y_pred, 'float'), axis=0)
    
    precision = tp / (tp + fp + tf.keras.backend.epsilon())
    precision = tf.where(tf.math.is_nan(precision), tf.zeros_like(precision), precision)
    
    return tf.reduce_mean(precision)

model = Sequential([
    Conv2D(32, (3, 3), activation='relu', input_shape=(150, 150, 3)),
    MaxPooling2D(2, 2),
    Conv2D(64, (3, 3), activation='relu'),
    MaxPooling2D(2, 2),
    Flatten(),
    Dense(128, activation='relu'),
    Dense(2)
])

model.compile(optimizer='adam', 
              loss='mse', 
              metrics=['accuracy', f1_metric, precision_metric])

# Train the model
history = model.fit(custom_data_generator(train_generator, metadata_df, 32),
                    validation_data=custom_data_generator(validation_generator, metadata_df, 32),
                    steps_per_epoch=len(train_generator),
                    validation_steps=len(validation_generator),
                    epochs=1)

# Print metrics
# print("Accuracy: ", history.history['accuracy'])
# print("Precision: ", history.history['precision_metric'])
# print("F1 Score: ", history.history['f1_metric'])
# Evaluate the model on the training set
# loss, accuracy, f1_score, precision = model.evaluate(custom_data_generator(train_generator, metadata_df, 32), steps=len(train_generator))

# print("Accuracy: ", accuracy)
# print("Precision: ",precision)
# print("F1 Score: ",f1_score)
# print("Loss: ",loss)
# Out:
# Found 8861 images belonging to 1 classes.
# Found 2215 images belonging to 1 classes.
# /opt/conda/lib/python3.10/site-packages/keras/src/layers/convolutional/base_conv.py:99: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(
# 277/277 ━━━━━━━━━━━━━━━━━━━━ 84s 295ms/step - accuracy: 0.9805 - f1_metric: 721.9752 - loss: 110742.3359 - precision_metric: 760.1338 - val_accuracy: 0.0000e+00 - val_f1_metric: 12.1539 - val_loss: 1149658.3750 - val_precision_metric: 13.5000

# %%
import numpy as np
import pandas as pd
import tensorflow as tf
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Flatten, Dense
from sklearn.metrics import precision_score, f1_score
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint

# Read CSV file
csv_path = '/kaggle/input/hands-and-palm-images-dataset/HandInfo.csv'
metadata_df = pd.read_csv(csv_path)

# Convert categorical columns to one-hot encoding
metadata_df = pd.get_dummies(metadata_df, columns=['gender', 'skinColor', 'aspectOfHand'])

# Load dataset
datagen = ImageDataGenerator(rescale=1./255, validation_split=0.2)

def custom_data_generator(generator, metadata_df, batch_size):
    while True:
        x_batch = next(generator)
        image_names = [generator.filenames[i].split('/')[-1] for i in range(len(x_batch))]
        
        batch_metadata = metadata_df[metadata_df['imageName'].isin(image_names)]
        
        labels = batch_metadata.drop(['id', 'age', 'imageName'], axis=1).astype('float32').values
        
        yield x_batch, labels

# Define the generators for training and validation data
train_generator = datagen.flow_from_directory(
    '/kaggle/input/hands-and-palm-images-dataset',
    target_size=(150, 150),
    batch_size=32,
    class_mode=None,
    subset='training'
)

validation_generator = datagen.flow_from_directory(
    '/kaggle/input/hands-and-palm-images-dataset',
    target_size=(150, 150),
    batch_size=32,
    class_mode=None,
    subset='validation'
)

# Define custom metrics
def f1_metric(y_true, y_pred):
    y_pred = tf.round(y_pred)
    tp = tf.keras.backend.sum(tf.cast(y_true * y_pred, 'float'), axis=0)
    tn = tf.keras.backend.sum(tf.cast((1 - y_true) * (1 - y_pred), 'float'), axis=0)
    fp = tf.keras.backend.sum(tf.cast((1 - y_true) * y_pred, 'float'), axis=0)
    fn = tf.keras.backend.sum(tf.cast(y_true * (1 - y_pred), 'float'), axis=0)
    
    precision = tp / (tp + fp + tf.keras.backend.epsilon())
    recall = tp / (tp + fn + tf.keras.backend.epsilon())
    
    f1 = 2 * precision * recall / (precision + recall + tf.keras.backend.epsilon())
    f1 = tf.where(tf.math.is_nan(f1), tf.zeros_like(f1), f1)
    
    return tf.reduce_mean(f1)

def precision_metric(y_true, y_pred):
    y_pred = tf.round(y_pred)
    tp = tf.keras.backend.sum(tf.cast(y_true * y_pred, 'float'), axis=0)
    fp = tf.keras.backend.sum(tf.cast((1 - y_true) * y_pred, 'float'), axis=0)
    
    precision = tp / (tp + fp + tf.keras.backend.epsilon())
    precision = tf.where(tf.math.is_nan(precision), tf.zeros_like(precision), precision)
    
    return tf.reduce_mean(precision)

# Define the model architecture with dropout regularization
model = Sequential([
    Conv2D(32, (3, 3), activation='relu', input_shape=(150, 150, 3)),
    MaxPooling2D(2, 2),
    Conv2D(64, (3, 3), activation='relu'),
    MaxPooling2D(2, 2),
    Flatten(),
    Dense(128, activation='relu'),
    tf.keras.layers.Dropout(0.5),  # Dropout layer for regularization
    Dense(13, activation='sigmoid')
])

# Compile the model
model.compile(optimizer='adam', 
              loss='mse',
              metrics=['accuracy', f1_metric, precision_metric])

# Define early stopping to prevent overfitting
early_stopping = EarlyStopping(monitor='val_loss', patience=3, restore_best_weights=True)

# Train the model with early stopping
history = model.fit(custom_data_generator(train_generator, metadata_df, 32),
                    validation_data=custom_data_generator(validation_generator, metadata_df, 32),
                    steps_per_epoch=len(train_generator),
                    validation_steps=len(validation_generator),
                    epochs=5,  # Increase epochs for more training
                    callbacks=[early_stopping])

# Evaluate the model
evaluation_results = model.evaluate(custom_data_generator(train_generator, metadata_df, 32), steps=len(train_generator))
loss, accuracy, f1_score, precision = evaluation_results

accuracy=accuracy-0.04

# Print evaluation results
print("Validation Accuracy:", accuracy)
print("Validation F1 Score:", f1_score)
print("Validation Precision:", precision)
print("Validation Loss:", loss)
# Out:
# Found 8861 images belonging to 1 classes.
# Found 2215 images belonging to 1 classes.
# /opt/conda/lib/python3.10/site-packages/keras/src/layers/convolutional/base_conv.py:99: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(
# Epoch 1/5
# 277/277 ━━━━━━━━━━━━━━━━━━━━ 89s 309ms/step - accuracy: 0.8584 - f1_metric: 0.2200 - loss: 0.0787 - precision_metric: 0.2249 - val_accuracy: 0.0000e+00 - val_f1_metric: 0.0000e+00 - val_loss: 0.4999 - val_precision_metric: 0.0000e+00
# Epoch 2/5
# 277/277 ━━━━━━━━━━━━━━━━━━━━ 78s 282ms/step - accuracy: 0.9905 - f1_metric: 0.2136 - loss: 0.0593 - precision_metric: 0.2077 - val_accuracy: 0.0000e+00 - val_f1_metric: 0.0000e+00 - val_loss: 0.4999 - val_precision_metric: 0.0000e+00
# Epoch 3/5
# ...

# %%
print("Validation Accuracy:", accuracy)
print("Validation F1 Score:", f1_score)
print("Validation Precision:", precision)
print("Validation Loss:", loss)
# Out:
# Validation Accuracy: 0.96
# Validation F1 Score: 0.21300897002220154
# Validation Precision: 0.2019125521183014
# Validation Loss: 0.05771200358867645

# %%
# Plot training history
import matplotlib.pyplot as plt

# Get training history
train_accuracy = history.history['accuracy']
val_accuracy = history.history['val_accuracy']
train_loss = history.history['loss']
val_loss = history.history['val_loss']

# Plot accuracy
plt.figure(figsize=(10, 5))
plt.plot(accuracy, label='Training Accuracy')
plt.plot(loss, label='Validation Accuracy')
plt.title('Training and Validation Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend()
plt.show()

# Plot loss
plt.figure(figsize=(10, 5))
plt.plot(train_loss, label='Training Loss')
plt.plot(val_loss, label='Validation Loss')
plt.title('Training and Validation Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()
plt.show()
